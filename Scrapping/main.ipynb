# %%
import pandas as pd

# %%
df=pd.read_csv("./all.csv")
df
# Out:
#     Unnamed: 0                                        description  \
# 0            0  Job Number 23116933\nJob Category Spa\nLocatio...
# 1            1  Job Number 23116947\nJob Category Food and Bev...
# 2            2  Job Number 23116938\nJob Category Food and Bev...
# 3            3  Overview\nThe Sales administrator & Deal Desk ...
# 4            4  ADP recruits a Team Leader\nAre you looking to...
# ..         ...                                                ...
# 95          95  Notre Campagne Alternance pour l'année 2023/20...
# 96          96  Please upload your English CV\nMicrosoft SQL D...
# 97          97   ADP sta reclutando Gestori dei salari  \nSei ...
# 98          98  KPMGaccompagne les sociétés et les groupes nat...
# 99          99  KPMGaccompagne les sociétés et les groupes nat...
#
#                         poste              entreprise            localisation  \
# 0             Attendant - Spa  Marriott International  Plusieurs Emplacements
# ...

# %%
df.shape
# Out:
# (100, 10)
